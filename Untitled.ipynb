# %%
import os

# Dataset path
dataset_path = r"C:\Users\DELL\OneDrive\Desktop\PlantVillage"

# Check color folder
color_path = os.path.join(dataset_path, "color")

if os.path.exists(color_path):
    print("✅ PlantVillage Color dataset mil gaya!")
    classes = os.listdir(color_path)
    print(f"\n📊 Total disease classes: {len(classes)}")
    print("\n🌿 Pehle 10 classes:")
    for i, cls in enumerate(classes[:10], 1):
        print(f"  {i}. {cls}")
    
    # Sample images count
    sample_class = classes[0]
    sample_images = os.listdir(os.path.join(color_path, sample_class))
    print(f"\n📸 '{sample_class}' mein images: {len(sample_images)}")
else:
    print("❌ Path check karo - PlantVillage folder Desktop pe hai?")
# Out:
# ❌ Path check karo - PlantVillage folder Desktop pe hai?

# %%
import os

# Sahi dataset path (space aur exact spelling ke saath)
dataset_path = r"C:\Users\DELL\OneDrive\Desktop\plantvillage dataset"

# Check color folder
color_path = os.path.join(dataset_path, "color")

if os.path.exists(color_path):
    print("✅ PlantVillage Color dataset mil gaya!")
    classes = os.listdir(color_path)
    print(f"\n📊 Total disease classes: {len(classes)}")
    print("\n🌿 Pehle 10 classes:")
    for i, cls in enumerate(classes[:10], 1):
        print(f"  {i}. {cls}")
    
    # Sample images count
    sample_class = classes[0]
    sample_images = os.listdir(os.path.join(color_path, sample_class))
    print(f"\n📸 '{sample_class}' mein images: {len(sample_images)}")
else:
    print("❌ Color folder nahi mila - folder structure check karo")
# Out:
# ✅ PlantVillage Color dataset mil gaya!
#
# 📊 Total disease classes: 38
#
# 🌿 Pehle 10 classes:
#   1. Apple___Apple_scab
#   2. Apple___Black_rot
#   3. Apple___Cedar_apple_rust
#   4. Apple___healthy
#   5. Blueberry___healthy
#   6. Cherry_(including_sour)___healthy
#   7. Cherry_(including_sour)___Powdery_mildew
#   8. Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
#   9. Corn_(maize)___Common_rust_
#   10. Corn_(maize)___healthy
#
# 📸 'Apple___Apple_scab' mein images: 630
